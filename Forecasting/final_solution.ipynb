# %%
# !pip3 install darts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting darts
#   Downloading darts-0.36.0-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 994.4 kB/s eta 0:00:00
# Collecting holidays>=0.11.1
#   Downloading holidays-0.75-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.16.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (1.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (3.10.3)
# Requirement already satisfied: narwhals>=1.25.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (1.41.0)
# Collecting nfoursid>=1.0.0
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (2.1.3)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (2.2.3)
# Collecting pyod>=0.9.5
#   Downloading pyod-2.0.5-py3-none-any.whl (200 kB)
#      -------------------------------------- 200.6/200.6 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (1.6.1)
# Requirement already satisfied: scipy<1.16.0,>=1.3.2 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (1.15.3)
# Collecting shap>=0.40.0
#   Downloading shap-0.48.0-cp311-cp311-win_amd64.whl (544 kB)
#      ------------------------------------ 544.4/544.4 kB 976.5 kB/s eta 0:00:00
# Collecting statsforecast>=1.4
#   Downloading statsforecast-2.0.2-cp311-cp311-win_amd64.whl (273 kB)
#      ------------------------------------ 273.5/273.5 kB 510.1 kB/s eta 0:00:00
# Collecting statsmodels>=0.14.0
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 796.4 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\ondra\appdata\roaming\python\python311\site-packages (from darts) (4.14.0)
# Collecting xarray>=0.17.0
#   Downloading xarray-2025.7.0-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 1.1 MB/s eta 0:00:00
# Collecting xgboost>=2.1.4
#   Downloading xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
#      ------------------------------------ 150.0/150.0 MB 922.1 kB/s eta 0:00:00
# Collecting pytorch-lightning>=1.5.0
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#      -------------------------------------- 825.4/825.4 kB 1.2 MB/s eta 0:00:00
# Collecting tensorboardX>=2.1
#   Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#      ---------------------------------------- 87.2/87.2 kB 1.2 MB/s eta 0:00:00
# Collecting torch>=1.8.0
#   Downloading torch-2.7.1-cp311-cp311-win_amd64.whl (216.1 MB)
#      ------------------------------------ 216.1/216.1 MB 656.8 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\ondra\appdata\roaming\python\python311\site-packages (from holidays>=0.11.1->darts) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->darts) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from pandas>=1.0.5->darts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from pandas>=1.0.5->darts) (2025.2)
# Collecting numba>=0.51
#   Downloading numba-0.61.2-cp311-cp311-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 2.8/2.8 MB 817.0 kB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from pytorch-lightning>=1.5.0->darts) (6.0.2)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from pytorch-lightning>=1.5.0->darts) (2025.5.1)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#      ------------------------------------ 963.5/963.5 kB 813.4 kB/s eta 0:00:00
# Collecting lightning-utilities>=0.10.0
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->darts) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->darts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->darts) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->darts) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from scikit-learn>=1.6.0->darts) (3.6.0)
# Collecting slicer==0.0.8
#   Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Collecting coreforecast>=0.0.12
#   Downloading coreforecast-0.0.16-cp311-cp311-win_amd64.whl (207 kB)
#      ------------------------------------ 207.7/207.7 kB 120.4 kB/s eta 0:00:00
# Collecting fugue>=0.8.1
#   Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
#      ------------------------------------- 278.2/278.2 kB 96.9 kB/s eta 0:00:00
# Collecting utilsforecast>=0.1.4
#   Downloading utilsforecast-0.2.12-py3-none-any.whl (42 kB)
#      -------------------------------------- 42.2/42.2 kB 226.8 kB/s eta 0:00:00
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ------------------------------------ 232.9/232.9 kB 203.5 kB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.20 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from tensorboardX>=2.1->darts) (5.29.5)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 685.7 kB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 700.4 kB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ------------------------------------ 134.9/134.9 kB 569.2 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\ondra\appdata\roaming\python\python311\site-packages (from tqdm>=4.60.0->darts) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (3.12.13)
# Collecting triad>=0.9.7
#   Downloading triad-0.9.8-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.3/62.3 kB 667.9 kB/s eta 0:00:00
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.6-py3-none-any.whl (19 kB)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=1.5.0->darts) (65.5.0)
# Collecting llvmlite<0.45,>=0.44.0dev0
#   Downloading llvmlite-0.44.0-cp311-cp311-win_amd64.whl (30.3 MB)
#      -------------------------------------- 30.3/30.3 MB 592.5 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from python-dateutil->holidays>=0.11.1->darts) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ------------------------------------ 536.2/536.2 kB 502.3 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.8.0->darts) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (6.6.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.20.1)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\ondra\appdata\roaming\python\python311\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (20.0.0)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ------------------------------------ 135.3/135.3 kB 235.4 kB/s eta 0:00:00
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: mpmath, appdirs, tensorboardX, sympy, slicer, patsy, networkx, llvmlite, lightning-utilities, jinja2, fs, filelock, coreforecast, cloudpickle, xgboost, torch, numba, holidays, xarray, utilsforecast, triad, torchmetrics, statsmodels, shap, pyod, nfoursid, pytorch-lightning, adagio, fugue, statsforecast, darts
# Successfully installed adagio-0.2.6 appdirs-1.4.4 cloudpickle-3.1.1 coreforecast-0.0.16 darts-0.36.0 filelock-3.18.0 fs-2.4.16 fugue-0.9.1 holidays-0.75 jinja2-3.1.6 lightning-utilities-0.14.3 llvmlite-0.44.0 mpmath-1.3.0 networkx-3.5 nfoursid-1.0.1 numba-0.61.2 patsy-1.0.1 pyod-2.0.5 pytorch-lightning-2.5.2 shap-0.48.0 slicer-0.0.8 statsforecast-2.0.2 statsmodels-0.14.4 sympy-1.14.0 tensorboardX-2.6.4 torch-2.7.1 torchmetrics-1.7.4 triad-0.9.8 utilsforecast-0.2.12 xarray-2025.7.0 xgboost-3.0.2
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import duckdb as ddb
import optuna 
import numpy as np

from darts import TimeSeries
from darts.models import LinearRegressionModel
from darts.dataprocessing.transformers import Scaler
from darts.metrics import rmse

from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
con = ddb.connect('kalam_hydropower.db',read_only = True)

# %%
# These are devices with weak signals which we can exclude from the analysis - these were mentioned in the samplesubmission notebook
devices_to_drop = ["3", "5", "11", "14", "15", "17", "24", "25", "27", "33", "4", "9"]

# %%
# It is clear from our sub-plots that there is a long period of 'no signal' in the data, so I'll use data from 2024-07-01 onward
# for simplicity and to avoid too much zero biasing. Ofcourse, the fillna(0) adds some degree of biasing as well
filtered_to_forecast_df = con.sql(
    """select
        date, source, consumer_device, data_user, kwh 
    from prepared.daily_hydropower_production
""").to_df()

filtered_to_forecast_df = filtered_to_forecast_df[~(filtered_to_forecast_df["consumer_device"].isin(devices_to_drop))]

filtered_to_forecast_pivotted_df = filtered_to_forecast_df.pivot(columns="source", index="date", values="kwh").copy()
filtered_to_forecast_pivotted_df.fillna(0, inplace=True)

filtered_to_forecast_df = filtered_to_forecast_pivotted_df.melt(value_vars=list(filtered_to_forecast_pivotted_df.columns), var_name="source", value_name="kwh", ignore_index=False)

filtered_to_forecast_df.reset_index(inplace=True, drop=False)


filtered_to_forecast_df = filtered_to_forecast_df[filtered_to_forecast_df["date"] >= pd.Timestamp("2024-07-01")]

filtered_to_forecast_df.head()
# Out:
#           date                          source  kwh
# 373 2024-07-01  consumer_device_10_data_user_1  0.0
# 374 2024-07-02  consumer_device_10_data_user_1  0.0
# 375 2024-07-03  consumer_device_10_data_user_1  0.0
# 376 2024-07-04  consumer_device_10_data_user_1  0.0
# 377 2024-07-05  consumer_device_10_data_user_1  0.0

# %%
# Now I acutally want to use the device, user and source as static covariates in darts, this is a bit of a roundabout
# way of getting to the values but this gets the consumer device and data user numbers back
filtered_to_forecast_df[['consumer_device', 'data_user']] = filtered_to_forecast_df['source'].str.extract(r'consumer_device_(\d+)_data_user_(\d+)')
filtered_to_forecast_df["consumer_device"] = filtered_to_forecast_df["consumer_device"].astype(int)
filtered_to_forecast_df["data_user"] = filtered_to_forecast_df["data_user"].astype(int)

# %%
features_df = con.sql(
    """
    SELECT
        *
    FROM prepared.daily_features
    """
).to_df()

features_df.head()
# Out:
#         date  avg_temperature  ...   sin_doy   cos_doy
# 0 2023-06-03         1.860280  ...  0.471160 -0.882048
# 1 2023-06-04         3.992740  ...  0.455907 -0.890028
# 2 2023-06-05         4.794523  ...  0.440519 -0.897743
# 3 2023-06-06         6.304390  ...  0.425000 -0.905193
# 4 2023-06-07         7.003922  ...  0.409356 -0.912375
#
# [5 rows x 20 columns]

# %%
# I setup a dictionary with a key per series, and a value containing the darts timeseries' incl. training, testing and scaled data
# as well as the individual scalers used to invert the transformation
ts_dict = {}

for series_name in filtered_to_forecast_df["source"].unique():
        
    try:

        series_ts = TimeSeries.from_dataframe(
            df=filtered_to_forecast_df[filtered_to_forecast_df["source"] == series_name],
            time_col="date",
            value_cols=["kwh"]
        )

        scaler = Scaler(StandardScaler())

        series_scaled_ts = scaler.fit_transform(series_ts)

        train_ts, test_ts = series_ts.split_after(len(series_ts) - 31)

        train_scaler = Scaler(StandardScaler())

        train_scaled_ts = train_scaler.fit_transform(train_ts)

    except Exception as e:
        print(f"Failed to process series {series_name} due to {e}")
        continue

    ts_dict[series_name] = {
        "ts": series_ts,
        "scaled_ts": series_scaled_ts,
        "scaler": scaler,
        "train_ts": train_ts,
        "train_scaled_ts": train_scaled_ts,
        "train_scaler": train_scaler,
        "test_ts": test_ts,
    }

# %%
# In darts you can pass a list of timeseries to a model's .fit function so that the model is trained on multiple series at once
train_ts_list = [ts_dict[series_name]["train_scaled_ts"] for series_name in ts_dict.keys()]

# These are the full series which we will use to train the final model
ts_list = [ts_dict[series_name]["scaled_ts"] for series_name in ts_dict.keys()]

# %%
# The features we want to use need to also be scaled so that they can be used with a model like LinearRegression
features_ts = TimeSeries.from_dataframe(features_df, time_col="date")

features_scaler = Scaler(StandardScaler())

scaled_features_ts = features_scaler.fit_transform(features_ts)

# %%
# I need the sample submission file to produce an 'accurate score' i.e. how well am I doing on the series that my model will
# actually be validated on
ss_df = pd.read_csv("./data/SampleSubmission.csv")
ss_df[["date", "source"]] = ss_df["ID"].str.split("_", expand=True, n=1)

ss_df["date"] = pd.to_datetime(ss_df["date"])

ss_df.head()
# Out:
#                                           ID  ...                          source
# 0  2024-09-24_consumer_device_12_data_user_1  ...  consumer_device_12_data_user_1
# 1  2024-09-25_consumer_device_12_data_user_1  ...  consumer_device_12_data_user_1
# 2  2024-09-26_consumer_device_12_data_user_1  ...  consumer_device_12_data_user_1
# 3  2024-09-27_consumer_device_12_data_user_1  ...  consumer_device_12_data_user_1
# 4  2024-09-28_consumer_device_12_data_user_1  ...  consumer_device_12_data_user_1
#
# [5 rows x 4 columns]

# %%
def score_model(model, ts_dict, ss_df, future_covs=None, forecast_horizon=31, scaled=False):
    """A utility function to score a model based on the data in the submission set"""

    rmse_scores = []

    series_to_forecast = set(ts_dict.keys()).intersection(set(ss_df["source"].unique()))

    for index, series_name in enumerate(series_to_forecast):

        predictions = model.predict(forecast_horizon, series=ts_dict[series_name]["train_scaled_ts"], future_covariates=future_covs[index], show_warnings=False)

        if scaled:
            predictions = ts_dict[series_name]["train_scaler"].inverse_transform(predictions)
        
        rmse_scores.append(rmse(ts_dict[series_name]["test_ts"], predictions))
    
    return np.mean(rmse_scores)

# %%
def create_predictions(model, ts_dict, ss_df, future_covs, forecast_horizon=31, scaled=False):
    """A utility function which can easily create a submission based on the sample submission file"""

    predictions_df = pd.DataFrame()

    series_to_forecast = set(ts_dict.keys()).intersection(set(ss_df["source"].unique()))

    for index, series_name in enumerate(series_to_forecast):

        predictions = model.predict(forecast_horizon, series=ts_dict[series_name]["scaled_ts"], future_covariates=future_covs[index])

        if scaled:
            predictions = ts_dict[series_name]["scaler"].inverse_transform(predictions)

        pred_df = predictions.to_dataframe()
        pred_df["source"] = series_name

        predictions_df = pd.concat([predictions_df, pred_df])


        predictions_df.sort_values(by=["source", "date"], inplace=True)

        predictions_df["ID"] = predictions_df.index.astype(str) + "_" + predictions_df["source"]

    return predictions_df

# %%
model_kwargs = {
    "lags": [-1],
    "output_chunk_length": 9,
    "lags_future_covariates": [-30],
    "use_static_covariates": False,
    "random_state": 42
}

# %%
## Setting up my model
linear_model = LinearRegressionModel(
    **model_kwargs
)

future_covs = [scaled_features_ts[['precip_snow_ratio']] for _ in range(len(train_ts_list))]

linear_model.fit(train_ts_list, future_covariates=future_covs)
# Out:
# LinearRegressionModel(lags=[-1], lags_past_covariates=None, lags_future_covariates=[-30], output_chunk_length=9, output_chunk_shift=0, add_encoders=None, likelihood=None, quantiles=None, random_state=42, multi_models=True, use_static_covariates=False)

# %%
score_model(linear_model, ts_dict, ss_df, future_covs, scaled=True)
# Out:
# np.float64(4.9103200288377105)

# %%
full_model = LinearRegressionModel(
    **model_kwargs
)

future_covs = [scaled_features_ts[['precip_snow_ratio']] for _ in range(len(ts_list))]

full_model.fit(ts_list, future_covariates=future_covs)
# Out:
# LinearRegressionModel(lags=[-1], lags_past_covariates=None, lags_future_covariates=[-30], output_chunk_length=9, output_chunk_shift=0, add_encoders=None, likelihood=None, quantiles=None, random_state=42, multi_models=True, use_static_covariates=False)

# %%
forecast_df = create_predictions(full_model, ts_dict, ss_df, future_covs, scaled=True)

forecast_df.head()
# Out:
#                  kwh  ...                                         ID
# date                  ...
# 2024-09-24  0.165820  ...  2024-09-24_consumer_device_12_data_user_1
# 2024-09-25  0.156552  ...  2024-09-25_consumer_device_12_data_user_1
# 2024-09-26  0.150046  ...  2024-09-26_consumer_device_12_data_user_1
# 2024-09-27  0.147673  ...  2024-09-27_consumer_device_12_data_user_1
# 2024-09-28  0.146711  ...  2024-09-28_consumer_device_12_data_user_1
#
# [5 rows x 3 columns]

# %%
forecast_df[["ID","kwh"]].to_csv("./Data/my_forecast.csv", index=False)
