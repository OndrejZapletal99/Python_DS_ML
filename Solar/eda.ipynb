# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Data Import

# %%
df_solar = pd.read_csv('Data/SEMS_data.csv')
df_solar.head()
# Out:
#         Datum           Elektrárna       Klasifikace  Kapacita(kW)  PV(kWh)  \
# 0  01.01.2024  HFVE Zapletal Simon  Úložiště baterie           7.6      1.2
# 1  02.01.2024  HFVE Zapletal Simon  Úložiště baterie           7.6      1.3
# 2  03.01.2024  HFVE Zapletal Simon  Úložiště baterie           7.6      1.9
# 3  04.01.2024  HFVE Zapletal Simon  Úložiště baterie           7.6      1.8
# 4  05.01.2024  HFVE Zapletal Simon  Úložiště baterie           7.6      4.5
#
#    Prodej(kWh)  Koupit(kWh)  Spotřeba(kWh)  Spotřebováno v domácnosti(kWh)  \
# 0         0.11        14.12          20.01                            5.89
# 1         0.11         6.32          12.21                            5.89
# 2         0.12         5.51          12.19                            6.68
# 3         0.15         6.13          11.78                            5.65
# 4         0.88         5.14          14.76                            9.62
#
#    Vlastní poměr(%)  Contribution Ratio(%)  Příjem(CZK)
# ...

# %%
df_weather = pd.read_csv('Data/weather.csv')
df_weather.head()
# Out:
#    Unnamed: 0    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0           0  2023-09-01     18.1      9.5  14.3          18.1           8.3
# 1           1  2023-09-02     21.3     15.0  17.7          21.3          15.0
# 2           2  2023-09-03     19.2     14.3  16.3          19.2          14.3
# 3           3  2023-09-04     18.5     11.9  14.7          18.5          11.9
# 4           4  2023-09-05     24.2      9.4  15.7          24.2           7.9
#
#    feelslike   dew  humidity  ...      normal.tempmax     normal.tempmin  \
# 0       14.2  10.4      77.7  ...  [11.5, 19.2, 31.5]  [6.9, 10.6, 16.2]
# 1       17.7  14.2      81.1  ...  [12.3, 18.5, 23.6]  [6.3, 10.4, 14.8]
# 2       16.3  12.6      79.9  ...  [11.0, 19.5, 25.8]  [5.7, 10.4, 15.2]
# 3       14.7   9.9      73.9  ...  [11.1, 19.3, 26.3]  [6.3, 10.8, 16.2]
# 4       15.4   9.9      71.2  ...   [7.7, 19.4, 27.4]  [3.4, 10.6, 14.7]
#
# ...

# %% [markdown]
# ## 1.2 Missing values
